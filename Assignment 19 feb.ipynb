# %%
What is Flask Framework? What are the advantages of Flask Framework?
Ans: Flask is a web application framework for Python. It is designed to be lightweight and modular, which makes it easy to use and flexible. 
Flask is popular among developers because it provides a simple yet powerful way to build web applications.

Some of the advantages of using Flask Framework are:

    Lightweight: Flask is lightweight and easy to learn, which makes it an excellent choice for small to medium-sized projects.

    Flexibility: Flask is very flexible, allowing developers to customize their applications to meet their specific needs.

    Easy to use: Flask's simple API makes it easy to get started with building web applications.

    Large community: Flask has a large community of developers, which means that there are plenty of resources available to help you with
    your project.

    Extensibility: Flask is extensible, which means that it can be easily integrated with other tools and libraries to add functionality.

    Well documented: Flask has extensive documentation and tutorials available, making it easy to learn and use.

    Testing: Flask has built-in support for testing, which allows developers to write tests to ensure that their applications are working as
    expected.

# %%
Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook
Ans:
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "<h1>Hello, World!</h1>"

if __name__=="__main__":
    app.run(host="0.0.0.0")

# %% [markdown]
# ![image.png](attachment:fa79a105-bac6-4e70-87a9-47b0ce6531ba.png)

# %%
What is App routing in Flask? Why do we use app routes?
Ans:
App routing in Flask is the process of mapping URLs to functions within a Flask application. In other words, 
it is the mechanism used to define the URLs that a user can visit and the corresponding code that will be executed when
the user visits those URLs.

In Flask, routing is achieved using the @app.route() decorator. The decorator is used to specify the URL pattern that the 
function should be mapped to. For example, if you want to map the root URL of your application to a function named home, 
you would use the @app.route() decorator like this:

python

@app.route('/')
def home():
    return 'This is the home page!'

In this example, the @app.route() decorator is used to map the root URL of the application (i.e., '/') to the home() function.
When a user visits the root URL of the application, Flask will execute the home() function and return the string 'This is the home page!'.

# %%
# Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” 
# route to show the following details:

#     Company Name: ABC Corporation
#     Location: India
#     Contact Detail: 999-999-9999
from flask import Flask

app = Flask(__name__)

@app.route('/welcome')
def welcome():
    return 'Welcome to ABC Corporation'

@app.route('/')
def company_details():
    return 'Company Name: ABC Corporation<br>Location: India<br>Contact Detail: 999-999-9999'

if __name__ == '__main__':
    app.run()

# %% [markdown]
# ![image.png](attachment:8688a816-b0f8-4e6d-8e8c-2405f730b31c.png)

# %%
# What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function
# Ans:
In Flask, the url_for() function is used for URL building. This function generates a URL for the specified endpoint with
the given method arguments.

Here's an example Flask application that demonstrates the working of the url_for() function:
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def home():
    return 'This is the home page!'

@app.route('/user/<name>')
def user_profile(name):
    return f'This is {name}\'s profile page!'

@app.route('/contact')
def contact():
    return 'This is the contact page!'

if __name__ == '__main__':
    with app.test_request_context():
        print(url_for('home'))
        print(url_for('user_profile', name='John'))
        print(url_for('contact'))
